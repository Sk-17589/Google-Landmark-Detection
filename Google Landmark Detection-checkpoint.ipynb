# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
from tensorflow import keras
import cv2
from matplotlib import pyplot as plt

# %%
import os
import random
from PIL import Image

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#                        id                                                url  \
# 0        6e158a47eb2ca3f6  https://upload.wikimedia.org/wikipedia/commons...
# 1        202cd79556f30760  http://upload.wikimedia.org/wikipedia/commons/...
# 2        3ad87684c99c06e1  http://upload.wikimedia.org/wikipedia/commons/...
# 3        e7f70e9c61e66af3  https://upload.wikimedia.org/wikipedia/commons...
# 4        4072182eddd0100e  https://upload.wikimedia.org/wikipedia/commons...
# ...                   ...                                                ...
# 4132909  fc0f007893b11ba7  https://upload.wikimedia.org/wikipedia/commons...
# 4132910  39aad18585867916  https://upload.wikimedia.org/wikipedia/commons...
# 4132911  fd0725460e4ebbec  https://upload.wikimedia.org/wikipedia/commons...
# 4132912  73691ae29e24ba19  https://upload.wikimedia.org/wikipedia/commons...
# 4132913  8ef8dff6fc4790c2  https://upload.wikimedia.org/wikipedia/commons...
#
#          landmark_id
# 0             142820
# 1             104169
# 2              37914
# 3             102140
# 4               2474
# ...              ...
# 4132909       172138
# 4132910       162860
# 4132911       191243
# 4132912       145760
# 4132913        34698
#
# [4132914 rows x 3 columns]

# %%
df = df.loc[df["id"].str.startswith('00', na=False), :]
num_classes = len(df["landmark_id"].unique())
num_data = len(df)

# %%
num_classes
# Out:
# 13589

# %%
num_data
# Out:
# 16157

# %%
data = pd.DataFrame(df["landmark_id"].value_counts())
data.reset_index(inplace = True)

# %%
data.head()
# Out:
#    landmark_id  count
# 0       138982     47
# 1        62798     18
# 2        83144     14
# 3       171772     13
# 4       176528     12

# %%
data.tail()
# Out:
#        landmark_id  count
# 13584        54986      1
# 13585       182355      1
# 13586        25204      1
# 13587       100559      1
# 13588        63972      1

# %%
data.columns = ['landmark_id', 'count']

# %%
data
# Out:
#        landmark_id  count
# 0           138982     47
# 1            62798     18
# 2            83144     14
# 3           171772     13
# 4           176528     12
# ...            ...    ...
# 13584        54986      1
# 13585       182355      1
# 13586        25204      1
# 13587       100559      1
# 13588        63972      1
#
# [13589 rows x 2 columns]

# %%
data['count'].describe()
# Out:
# count    13589.000000
# mean         1.188976
# std          0.727458
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         47.000000
# Name: count, dtype: float64

# %%
plt.hist(data['count'], 100, range =(0,64), label = 'test')
# Out:
# (array([0.0000e+00, 1.1789e+04, 0.0000e+00, 1.3960e+03, 2.5400e+02,
#         0.0000e+00, 7.6000e+01, 3.4000e+01, 0.0000e+00, 2.0000e+01,
#         9.0000e+00, 0.0000e+00, 3.0000e+00, 0.0000e+00, 1.0000e+00,
#         2.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#  array([ 0.  ,  0.64,  1.28,  1.92,  2.56,  3.2 ,  3.84,  4.48,  5.12,
#          5.76,  6.4 ,  7.04,  7.68,  8.32,  8.96,  9.6 , 10.24, 10.88,
#         11.52, 12.16, 12.8 , 13.44, 14.08, 14.72, 15.36, 16.  , 16.64,
#         17.28, 17.92, 18.56, 19.2 , 19.84, 20.48, 21.12, 21.76, 22.4 ,
#         23.04, 23.68, 24.32, 24.96, 25.6 , 26.24, 26.88, 27.52, 28.16,
#         28.8 , 29.44, 30.08, 30.72, 31.36, 32.  , 32.64, 33.28, 33.92,
#         34.56, 35.2 , 35.84, 36.48, 37.12, 37.76, 38.4 , 39.04, 39.68,
#         40.32, 40.96, 41.6 , 42.24, 42.88, 43.52, 44.16, 44.8 , 45.44,
#         46.08, 46.72, 47.36, 48.  , 48.64, 49.28, 49.92, 50.56, 51.2 ,
#         51.84, 52.48, 53.12, 53.76, 54.4 , 55.04, 55.68, 56.32, 56.96,
#         57.6 , 58.24, 58.88, 59.52, 60.16, 60.8 , 61.44, 62.08, 62.72,
#         63.36, 64.  ]),
#  <BarContainer object of 100 artists>)

# %%
data['count'].between(0,5).sum()
# Out:
# 13549

# %%
data['count'].between(5,10).sum()
# Out:
# 69

# %%
data['count'].between(10,15).sum()
# Out:
# 5

# %%
hist, bins = np.histogram(df["landmark_id"], bins=df["landmark_id"].nunique())

# Plot the histogram
plt.hist(df["landmark_id"], bins=bins)
plt.xlabel("Landmark ID")
plt.ylabel("Frequency")
plt.title("Landmark ID Histogram")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
labelencoder.fit(df["landmark_id"])
# Out:
# LabelEncoder()

# %%
df
# Out:
#                        id                                                url  \
# 108      0036d78c05c194d9  https://upload.wikimedia.org/wikipedia/commons...
# 172      00c08b162f34f53f  https://upload.wikimedia.org/wikipedia/commons...
# 710      00e5d77c905d94a6  https://upload.wikimedia.org/wikipedia/commons...
# 1256     00c8dba0df4d112a  https://upload.wikimedia.org/wikipedia/commons...
# 1262     001cd787f1e9a803  https://upload.wikimedia.org/wikipedia/commons...
# ...                   ...                                                ...
# 4131341  0069f71dc6c5dac0  http://upload.wikimedia.org/wikipedia/commons/...
# 4131349  00f1aecb6c90b551  https://upload.wikimedia.org/wikipedia/commons...
# 4131698  00de9755a042c271  https://upload.wikimedia.org/wikipedia/commons...
# 4132109  009cb0761e9b3ce1  https://upload.wikimedia.org/wikipedia/commons...
# 4132228  00061f402c08f27f  https://upload.wikimedia.org/wikipedia/commons...
#
#          landmark_id
# 108            50089
# 172           163404
# 710            26066
# 1256           35744
# 1262           61937
# ...              ...
# 4131341        51272
# 4131349        63972
# 4131698        73064
# 4132109        68657
# 4132228       193078
#
# [16157 rows x 3 columns]

# %%
def encode_label(label):
    return labelencoder.transform(label)

# %%
def decode_label(label):
    return labelencoder.inverse_transform(label)

# %%
base_path = "./images_000/"

# %%
def get_img_from_num(num, df):
    row = df.iloc[num, :]
    fname = row['id'] 
    label = row['landmark_id']
    fname = fname + ".jpg"
    f1 = fname[0]
    f2 = fname[1]
    f3 = fname[2]
    path = os.path.join(base_path, f1, f2, f3, fname)
    img = cv2.imread(path)
    if img is None or img.shape[2] != 3 or img.dtype != np.uint8:
        print("Error loading or invalid image:", path)
        return None, None
    return img, label

# %%
print("4 Sample Images from random classes")
fig = plt.figure(figsize=(16,16))
for i in range(1,5):
    ri = random.choices(os.listdir(base_path), k=3)
    folder = base_path + '/' + ri[0] + '/' + ri[1] + '/' + ri[2]
    random_img = random.choice(os.listdir(folder))
    img = np.array(Image.open(folder+'/'+random_img))
    fig.add_subplot(1,4,i)
    plt.imshow(img)
    plt.axis('off')
plt.show()
# Out:
# 4 Sample Images from random classes

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.compat.v1.keras.layers import *
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import RMSprop
tf.compat.v1.disable_eager_execution()

# %%
#Parameters
learning_rate = 0.0001
decay_speed = 1e-6
momentum = 0.09
loss_function = "sparse_categorical_crossentropy"
source_model = VGG19(weights=None)
drop_layer = Dropout(0.5)
drop_layer2 = Dropout(0.5)

# %%
model = Sequential()
for layer in source_model.layers[:-1]:
    if layer == source_model.layers[-25]:
        model.add(BatchNormalization())
    model.add(layer)
model.add(Dense(num_classes, activation = "softmax"))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Sashank\anaconda3\envs\myenv\lib\site-packages\keras\layers\normalization\batch_normalization.py:562: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 224, 224, 3)      12
#  ormalization)
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense (Dense)               (None, 13589)             55674133
#
# =================================================================
# Total params: 195,244,385
# Trainable params: 195,244,379
# Non-trainable params: 6
# _________________________________________________________________

# %%
model.compile(optimizer = keras.optimizers.RMSprop(lr=learning_rate),
                                                    loss=loss_function,
                                                    metrics = ["accuracy"])
# Out:
# C:\Users\Sashank\anaconda3\envs\myenv\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:140: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
def image_reshape(img, target_size):
    return cv2.resize(img, target_size)

# %%
def get_batch(dataframe, start, batch_size):
    image_array = []
    label_array = []

    end_image = start + batch_size
    if end_image > len(dataframe):
        end_image = len(dataframe)

    for idx in range(start, end_image):
        n = idx
        img, label = get_img_from_num(n, dataframe)

        # Check if the img is None or not a valid image
        if img is None or img.shape[2] != 3 or img.dtype != np.uint8:
            continue  

        img = image_reshape(img, (224, 224)) / 255.0
        image_array.append(img)
        label_array.append(label)

    label_array = encode_label(label_array)
    label_array = label_array.astype(np.int32)

    return np.array(image_array, dtype=np.float32), label_array

# %%
batch_size = 64
epoch_shuffle = True
weight_classes = True
epochs = 1

#split 
train, val = np.split(df.sample(frac=1), [int(0.8*len(df))])
print(len(train))
print(len(val))
# Out:
# 12925
# 3232

# %%
for e in range(epochs):
    print("Epoch: ", str(e+1) + "/" + str(epochs))
    if epoch_shuffle:
        train = train.sample(frac = 1)
    for it in range(int(np.ceil(len(train)/batch_size))):
        X_train, y_train = get_batch(train, it*batch_size, batch_size)
        model.train_on_batch(X_train, y_train)
        

model.save("Model")
# Out:
# Epoch:  1/1
# Error loading or invalid image: ./images_000/0\0\7\007944f38e614910.jpg
# Error loading or invalid image: ./images_000/0\0\9\009c6830dcc07472.jpg
# Error loading or invalid image: ./images_000/0\0\9\009abf95b917462d.jpg
# Error loading or invalid image: ./images_000/0\0\b\00b03faa153f525a.jpg
# Error loading or invalid image: ./images_000/0\0\c\00c33c6f90f44516.jpg
# Error loading or invalid image: ./images_000/0\0\e\00e6531e91104c67.jpg
# Error loading or invalid image: ./images_000/0\0\6\0067d9df2e4c8aa1.jpg
# Error loading or invalid image: ./images_000/0\0\7\007c06b090134750.jpg
# Error loading or invalid image: ./images_000/0\0\8\008dfe0df67c36aa.jpg
# Error loading or invalid image: ./images_000/0\0\8\008892cef747b25e.jpg
# Error loading or invalid image: ./images_000/0\0\4\0046b5545d72c09c.jpg
# Error loading or invalid image: ./images_000/0\0\d\00df131001b4658d.jpg
# Error loading or invalid image: ./images_000/0\0\a\00a521c0ac2da881.jpg
# Error loading or invalid image: ./images_000/0\0\f\00facdda5029ebf7.jpg
# Error loading or invalid image: ./images_000/0\0\2\002f3fe7326d762d.jpg
# Error loading or invalid image: ./images_000/0\0\2\00266db21bcdb9c0.jpg
# Error loading or invalid image: ./images_000/0\0\1\001ce19c4846f959.jpg
# Error loading or invalid image: ./images_000/0\0\7\007a0743d4248328.jpg
# Error loading or invalid image: ./images_000/0\0\c\00c79b42c21fd000.jpg
# Error loading or invalid image: ./images_000/0\0\1\001f4b4e27425dbd.jpg
# Error loading or invalid image: ./images_000/0\0\e\00e6fa7e818a99ea.jpg
# Error loading or invalid image: ./images_000/0\0\8\008bf9ab39e1d30d.jpg
# Error loading or invalid image: ./images_000/0\0\4\00409f5bf2d1f0ab.jpg
# Error loading or invalid image: ./images_000/0\0\d\00de84a4b4ee7f0e.jpg
# Error loading or invalid image: ./images_000/0\0\c\00cbb8c0e11e7ee3.jpg
# Error loading or invalid image: ./images_000/0\0\c\00c5b41595797913.jpg
# Error loading or invalid image: ./images_000/0\0\3\0036a943bb8756ef.jpg
# Error loading or invalid image: ./images_000/0\0\8\0086e675b1e195fe.jpg
# Error loading or invalid image: ./images_000/0\0\e\00e1b504ce961ffe.jpg
# Error loading or invalid image: ./images_000/0\0\b\00bbef93b987b98a.jpg
# Error loading or invalid image: ./images_000/0\0\5\0059e724db1c3f3e.jpg
# Error loading or invalid image: ./images_000/0\0\3\003c64e285ddaf66.jpg
# Error loading or invalid image: ./images_000/0\0\d\00dc880db8c66b7f.jpg
# Error loading or invalid image: ./images_000/0\0\5\005c6fabd50c3ffc.jpg
# Error loading or invalid image: ./images_000/0\0\2\002951deb03dce74.jpg
# Error loading or invalid image: ./images_000/0\0\6\0065ebb79683b1b5.jpg
# Error loading or invalid image: ./images_000/0\0\f\00f98dff934be7ae.jpg
# Error loading or invalid image: ./images_000/0\0\4\00402c3d4bf94e0d.jpg
# Error loading or invalid image: ./images_000/0\0\2\002c5c0742260706.jpg
# Error loading or invalid image: ./images_000/0\0\6\0066c65d237d541b.jpg
# Error loading or invalid image: ./images_000/0\0\f\00fcbf4f6012a58e.jpg
# Error loading or invalid image: ./images_000/0\0\5\00535560b050e20c.jpg
# Error loading or invalid image: ./images_000/0\0\7\00788f55f220ab0a.jpg
# Error loading or invalid image: ./images_000/0\0\8\008f872425861025.jpg
# Error loading or invalid image: ./images_000/0\0\0\000bbba9e3b60311.jpg
# Error loading or invalid image: ./images_000/0\0\b\00bb4dfb947a0429.jpg
# Error loading or invalid image: ./images_000/0\0\0\00015a0a9af3b0f0.jpg
# Error loading or invalid image: ./images_000/0\0\2\002a983ac08f8375.jpg
# Error loading or invalid image: ./images_000/0\0\2\0021b490850cff65.jpg
# Error loading or invalid image: ./images_000/0\0\a\00a15d58ddd7d94d.jpg
# Error loading or invalid image: ./images_000/0\0\b\00b26c4e3d7d58b2.jpg
# Error loading or invalid image: ./images_000/0\0\f\00f493c9f9810061.jpg
# Error loading or invalid image: ./images_000/0\0\8\008cfc22ef14d394.jpg
# Error loading or invalid image: ./images_000/0\0\4\004e0394b091ec5d.jpg
# Error loading or invalid image: ./images_000/0\0\3\003ba76e29afd3bd.jpg
# Error loading or invalid image: ./images_000/0\0\d\00d4f82bb3829656.jpg
# Error loading or invalid image: ./images_000/0\0\b\00bcc565fb4aa01c.jpg
# Error loading or invalid image: ./images_000/0\0\e\00edd683b9410ec2.jpg
# Error loading or invalid image: ./images_000/0\0\8\00897f8dd82c052f.jpg
# Error loading or invalid image: ./images_000/0\0\9\009165a3ab61fefc.jpg
# Error loading or invalid image: ./images_000/0\0\9\009817a6e1b7e2f6.jpg
# Error loading or invalid image: ./images_000/0\0\b\00b513c4ff706a9c.jpg
# Error loading or invalid image: ./images_000/0\0\3\00376c03bf158f6d.jpg
# Error loading or invalid image: ./images_000/0\0\4\00400e45f52c132a.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 7
#       5     for it in range(int(np.ceil(len(train)/batch_size))):
#       6         X_train, y_train = get_batch(train, it*batch_size, batch_size)
# ----> 7         model.train_on_batch(X_train, y_train)
#      10 model.save("Model")
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_v1.py:1145, in Model.train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1140     raise NotImplementedError(
#    1141         "`train_on_batch` is not supported for models "
#    1142         "distributed with tf.distribute.Strategy."
#    1143     )
#    1144 # Validate and standardize user data.
# -> 1145 x, y, sample_weights = self._standardize_user_data(
#    1146     x,
#    1147     y,
#    1148     sample_weight=sample_weight,
#    1149     class_weight=class_weight,
#    1150     extract_tensors_from_dataset=True,
#    1151 )
#    1153 # If `self._distribution_strategy` is True, then we are in a replica
#    1154 # context at this point because of the check above.  `train_on_batch` is
#    1155 # being run for each replica by `self._distribution_strategy` and the
#    1156 # same code path as Eager is expected to be taken.
#    1157 if self.run_eagerly or self._distribution_strategy:
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_v1.py:2649, in Model._standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2640 if (
#    2641     not run_eagerly
#    2642     and is_build_called
#    (...)
#    2645     and any(_is_symbolic_tensor(v) for v in all_inputs)
#    2646 ):
#    2647     return [], [], None
# -> 2649 return self._standardize_tensors(
#    2650     x,
#    2651     y,
#    2652     sample_weight,
#    2653     run_eagerly=run_eagerly,
#    2654     dict_inputs=dict_inputs,
#    2655     is_dataset=is_dataset,
#    2656     class_weight=class_weight,
#    2657     batch_size=batch_size,
#    2658 )
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_v1.py:2690, in Model._standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs, is_dataset, class_weight, batch_size)
#    2687 # Standardize the inputs.
#    2688 if not isinstance(x, (tf.compat.v1.data.Dataset, tf.data.Dataset)):
#    2689     # TODO(fchollet): run static checks with dataset output shape(s).
# -> 2690     x = training_utils_v1.standardize_input_data(
#    2691         x,
#    2692         feed_input_names,
#    2693         feed_input_shapes,
#    2694         check_batch_axis=False,  # Don't enforce the batch size.
#    2695         exception_prefix="input",
#    2696     )
#    2698 # Get typespecs for the input data and sanitize it if necessary.
#    2699 # TODO(momernick): This should be capable of doing full input validation
#    2700 # at all times - validate that this is so and refactor the
#    2701 # standardization code.
#    2702 if isinstance(x, tf.data.Dataset):
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_utils_v1.py:714, in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     712 shape = shapes[i]
#     713 if len(data_shape) != len(shape):
# --> 714     raise ValueError(
#     715         "Error when checking "
#     716         + exception_prefix
#     717         + ": expected "
#     718         + names[i]
#     719         + " to have "
#     720         + str(len(shape))
#     721         + " dimensions, but got array "
#     722         "with shape " + str(data_shape)
#     723     )
#     724 if not check_batch_axis:
#     725     data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected input_1 to have 4 dimensions, but got array with shape (0, 1)

# %%
### Test on training set
batch_size = 16

errors = 0
good_preds = []
bad_preds = []

for it in range(int(np.ceil(len(val)/batch_size))):

    X_train, y_train = get_batch(val, it*batch_size, batch_size)

    result = model.predict(X_train)
    cla = np.argmax(result, axis=1)
    for idx, res in enumerate(result):
        if cla[idx] != y_train[idx]:
            errors = errors + 1
            bad_preds.append([batch_size*it + idx, cla[idx], res[cla[idx]]])
        else:
            good_preds.append([batch_size*it + idx, cla[idx], res[cla[idx]]])
# Out:
# Error loading or invalid image: ./images_000/0\0\f\00f21986a54810b0.jpg
# Error loading or invalid image: ./images_000/0\0\c\00ce9c6c9799f3ea.jpg
# Error loading or invalid image: ./images_000/0\0\b\00bd133629c22f4e.jpg
# Error loading or invalid image: ./images_000/0\0\a\00a5eba7e40d1023.jpg
# Error loading or invalid image: ./images_000/0\0\0\00052037272020e2.jpg
# Error loading or invalid image: ./images_000/0\0\3\003e3893c581e568.jpg
# Error loading or invalid image: ./images_000/0\0\7\00751235f056f9da.jpg
# Error loading or invalid image: ./images_000/0\0\7\00729fe473739529.jpg
# Error loading or invalid image: ./images_000/0\0\1\0010ccea97cc4542.jpg
# Error loading or invalid image: ./images_000/0\0\5\005925e45ebda9ad.jpg
# Error loading or invalid image: ./images_000/0\0\b\00bd8f6368aa5e16.jpg
# Error loading or invalid image: ./images_000/0\0\e\00e686dbf5e0d4e5.jpg
# Error loading or invalid image: ./images_000/0\0\c\00c08b162f34f53f.jpg
# Error loading or invalid image: ./images_000/0\0\5\005063fc13b566ff.jpg
# Error loading or invalid image: ./images_000/0\0\6\006085de349eed69.jpg
# Error loading or invalid image: ./images_000/0\0\b\00ba49afcdbe6569.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 12
#       8 for it in range(int(np.ceil(len(val)/batch_size))):
#      10     X_train, y_train = get_batch(val, it*batch_size, batch_size)
# ---> 12     result = model.predict(X_train)
#      13     cla = np.argmax(result, axis=1)
#      14     for idx, res in enumerate(result):
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_v1.py:1058, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1055 self._check_call_args("predict")
#    1057 func = self._select_training_loop(x)
# -> 1058 return func.predict(
#    1059     self,
#    1060     x=x,
#    1061     batch_size=batch_size,
#    1062     verbose=verbose,
#    1063     steps=steps,
#    1064     callbacks=callbacks,
#    1065     max_queue_size=max_queue_size,
#    1066     workers=workers,
#    1067     use_multiprocessing=use_multiprocessing,
#    1068 )
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_arrays_v1.py:798, in ArrayLikeTrainingLoop.predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     787 def predict(
#     788     self,
#     789     model,
#    (...)
#     795     **kwargs
#     796 ):
#     797     batch_size = model._validate_or_infer_batch_size(batch_size, steps, x)
# --> 798     x, _, _ = model._standardize_user_data(
#     799         x, check_steps=True, steps_name="steps", steps=steps
#     800     )
#     801     return predict_loop(
#     802         model,
#     803         x,
#    (...)
#     807         callbacks=callbacks,
#     808     )
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_v1.py:2649, in Model._standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2640 if (
#    2641     not run_eagerly
#    2642     and is_build_called
#    (...)
#    2645     and any(_is_symbolic_tensor(v) for v in all_inputs)
#    2646 ):
#    2647     return [], [], None
# -> 2649 return self._standardize_tensors(
#    2650     x,
#    2651     y,
#    2652     sample_weight,
#    2653     run_eagerly=run_eagerly,
#    2654     dict_inputs=dict_inputs,
#    2655     is_dataset=is_dataset,
#    2656     class_weight=class_weight,
#    2657     batch_size=batch_size,
#    2658 )
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_v1.py:2690, in Model._standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs, is_dataset, class_weight, batch_size)
#    2687 # Standardize the inputs.
#    2688 if not isinstance(x, (tf.compat.v1.data.Dataset, tf.data.Dataset)):
#    2689     # TODO(fchollet): run static checks with dataset output shape(s).
# -> 2690     x = training_utils_v1.standardize_input_data(
#    2691         x,
#    2692         feed_input_names,
#    2693         feed_input_shapes,
#    2694         check_batch_axis=False,  # Don't enforce the batch size.
#    2695         exception_prefix="input",
#    2696     )
#    2698 # Get typespecs for the input data and sanitize it if necessary.
#    2699 # TODO(momernick): This should be capable of doing full input validation
#    2700 # at all times - validate that this is so and refactor the
#    2701 # standardization code.
#    2702 if isinstance(x, tf.data.Dataset):
#
# File ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training_utils_v1.py:714, in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     712 shape = shapes[i]
#     713 if len(data_shape) != len(shape):
# --> 714     raise ValueError(
#     715         "Error when checking "
#     716         + exception_prefix
#     717         + ": expected "
#     718         + names[i]
#     719         + " to have "
#     720         + str(len(shape))
#     721         + " dimensions, but got array "
#     722         "with shape " + str(data_shape)
#     723     )
#     724 if not check_batch_axis:
#     725     data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected input_1 to have 4 dimensions, but got array with shape (0, 1)

# %%
#Good predictions
good_preds = np.array(good_preds)
good_preds = np.array(sorted(good_preds, key = lambda x: x[2], reverse=True))

fig=plt.figure(figsize=(16, 16))
for i in range(1,6):
    n = int(good_preds[i,0])
    img, lbl = get_img_from_num(n, val)
    if img is None:
        continue
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    fig.add_subplot(1, 5, i)
    plt.imshow(img)
    lbl2 = np.array(int(good_preds[i,1])).reshape(1,1)
    sample_cnt = list(df.landmark_id).count(lbl)
    plt.title("Label: " + str(lbl) + "\nClassified as: " + str(decode_label(lbl2)) + "\nSamples in class " + str(lbl) + ": " + str(sample_cnt))
    plt.axis('off')
plt.show()
# Out:
# Error loading or invalid image: ./images_000/0\0\b\00b7587a137637cd.jpg
